# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
from itertools import combinations
print(os.listdir("../module_1/"))
# Out:
# ['data.csv', 'test.ipynb', '[SF-DST] Movies IMBD v3.0.ipynb', '.ipynb_checkpoints', 'copy_proj.ipynb']

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
#Парсинг даты
parsed_release_date = pd.DataFrame(data.release_date.str.split('\/').tolist())
parsed_release_date.columns = ['month', 'day', 'year']
data.release_date = pd.to_datetime(parsed_release_date)

#Делаю универсальное название для Warner Bros, правда из-за этого получил единственную ошибку
data.production_companies=data.production_companies.apply(lambda x: str(x).replace('Warner Bros. Pictures','Warner Bros.'))
#Расчет прибыли
data.loc[:, 'profit'] = data['revenue'] - data['budget']

answer_ls = []  # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
display(
    data.sort_values(by='budget', ascending=False).head(10))
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 491   tt1032751    0.250540  425000000    11087569
# 724   tt1298650    4.955130  380000000  1021683000
# 1670  tt0449088    4.965391  300000000   961000000
# 14    tt2395427    5.944927  280000000  1405035767
# 1015  tt0401729    1.588457  260000000   284139100
# 380   tt0398286    2.865684  260000000   591794936
# 1677  tt0413300    2.520912  258000000   890871626
# 1246  tt1210819    1.214510  255000000    89289910
# 123   tt2310332   10.174599  250000000   955119788
# 1187  tt1170358    4.310786  250000000   958400000
#
#                                    original_title  \
# 491                             The Warrior's Way
# 724   Pirates of the Caribbean: On Stranger Tides
# 1670     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1015                                  John Carter
# 380                                       Tangled
# ...

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
display(
    data.sort_values(by='runtime', ascending=False).head(10))
answer_ls.append(2)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1158  tt0279111    0.469518   56000000    12923936
# 1082  tt0167260    7.122455   94000000  1118888979
# 1737  tt0462322    0.906938   67000000    25037897
# 1337  tt0360717    1.508329  207000000   550000000
# 505   tt0213149    2.478879  140000000   449220945
# 1184  tt0993846    4.877927  100000000   392000694
# 864   tt0167261    8.095275   79000000   926287400
# 497   tt0120737    8.575419   93000000   871368364
# 1602  tt0346491    1.319068  155000000   167298192
# 994   tt1371111    2.478372  102000000   130482868
#
#                                          original_title  \
# 1158                                  Gods and Generals
# 1082      The Lord of the Rings: The Return of the King
# 1737                                         Grindhouse
# 1337                                          King Kong
# 505                                        Pearl Harbor
# 1184                            The Wolf of Wall Street
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
display(
    data.sort_values(by='runtime', ascending=True).head(10))
answer_ls.append(3)
# Out:
#         imdb_id  popularity     budget    revenue            original_title  \
# 769   tt1449283    1.425344   30000000   14460000           Winnie the Pooh
# 931   tt0280030    0.678896   20000000  109862682      Return to Never Land
# 1098  tt0283426    1.781615   20000000  135680000         The Jungle Book 2
# 1627  tt0299172    0.837906  110000000  103951461         Home on the Range
# 1409  tt0361089    0.558258   35000000   19478106                   Valiant
# 1349  tt0121164    1.265401   40000000  117195061              Corpse Bride
# 885   tt0243585    1.594587  120000000  169956806           Stuart Little 2
# 1808  tt0120917    1.768463  100000000  169327687  The Emperor's New Groove
# 252   tt0472033    2.846465   30000000   48428063                         9
# 1769  tt0452702    0.504782   19000000   35300645                   Vacancy
#
#                                                    cast  \
# 769   Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
# ...

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
display(np.round(data.runtime.mean()))
answer_ls.append(2)
# Out:
# 110.0

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
display(np.round(data.runtime.median()))
answer_ls.append(1)
# Out:
# 106.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
display(data.sort_values(by='profit', ascending=False).head(10))
answer_ls.append(5)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 239   tt0499549    9.432768  237000000  2781505847
# 3     tt2488496   11.173104  200000000  2068178225
# 0     tt0369610   32.985763  150000000  1513528810
# 4     tt2820852    9.335014  190000000  1506249360
# 971   tt0848228    7.637767  220000000  1519557910
# 723   tt1201607    5.711315  125000000  1327817822
# 14    tt2395427    5.944927  280000000  1405035767
# 1178  tt2294629    6.112766  150000000  1274219009
# 8     tt2293640    7.404165   74000000  1156730962
# 1082  tt0167260    7.122455   94000000  1118888979
#
#                                      original_title  \
# 239                                          Avatar
# 3                      Star Wars: The Force Awakens
# 0                                    Jurassic World
# 4                                         Furious 7
# 971                                    The Avengers
# 723    Harry Potter and the Deathly Hallows: Part 2
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
display(data.sort_values(by='profit', ascending=True).head(10))
answer_ls.append(2)
# Out:
#         imdb_id  popularity     budget   revenue  \
# 491   tt1032751    0.250540  425000000  11087569
# 1246  tt1210819    1.214510  255000000  89289910
# 1617  tt0318974    0.948560  145000000  25819961
# 810   tt1305591    0.921653  150000000  38992758
# 959   tt0180052    0.912373  100000000   7103973
# 1465  tt0424095    1.390297  149000000  64459316
# 637   tt0455824    1.468543  130000000  49554002
# 1873  tt0134983    0.385350   90000000  14828081
# 1401  tt0318081    0.626900   80000000   5989640
# 1719  tt0211933    1.142781   86000000  14373825
#
#                     original_title  \
# 491              The Warrior's Way
# 1246               The Lone Ranger
# 1617                     The Alamo
# 810                Mars Needs Moms
# 959   The Adventures of Pluto Nash
# 1465                  Flushed Away
# 637                      Australia
# 1873                     Supernova
# 1401            A Sound of Thunder
# 1719                         Awake
#
# ...

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
display(data.query('profit > 0').profit.count())
answer_ls.append(1)
# Out:
# 1478

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
display(
    data.query('release_year == 2008').sort_values(by='profit',
                                                   ascending=False))
answer_ls.append(4)
# Out:
#        imdb_id  popularity     budget     revenue  \
# 600  tt0468569    8.466668  185000000  1001921825
# 604  tt0367882    3.161670  185000000   786636033
# 608  tt0795421    2.543535   52000000   609841637
# 607  tt0441773    3.036644  130000000   631744560
# 622  tt0448157    1.800286  150000000   624029371
# ..         ...         ...        ...         ...
# 669  tt0811080    0.879116  120000000    93945766
# 706  tt0469903    0.450911   40000000     9793496
# 683  tt0970411    0.721663   55000000    17869048
# 680  tt0462465    0.749838   50000000     7033683
# 637  tt0455824    1.468543  130000000    49554002
#
#                                         original_title  \
# 600                                    The Dark Knight
# 604  Indiana Jones and the Kingdom of the Crystal S...
# 608                                         Mamma Mia!
# 607                                      Kung Fu Panda
# 622                                            Hancock
# ...

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
display(
    data.query('release_year in [2012,2013,2014]').sort_values(by='profit',
                                                               ascending=True))
answer_ls.append(5)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1246  tt1210819    1.214510  255000000    89289910
# 1215  tt0790736    1.689869  130000000    61648500
# 1008  tt1374992    1.690572   60000000     8106475
# 1303  tt0884726    0.354271   70000000    18662027
# 1236  tt1308729    1.319947   55000000     9489829
# ...         ...         ...        ...         ...
# 1190  tt1690953    3.928789   76000000   970761885
# 975   tt1074638    5.603587  200000000  1108561013
# 1181  tt1300854    4.946136  200000000  1215439994
# 1178  tt2294629    6.112766  150000000  1274219009
# 971   tt0848228    7.637767  220000000  1519557910
#
#                        original_title  \
# 1246                  The Lone Ranger
# 1215                         R.I.P.D.
# 1008                      Upside Down
# 1303  Legends of Oz: Dorothy's Return
# 1236               Bullet to the Head
# ...                               ...
# 1190                  Despicable Me 2
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
df_genre = pd.DataFrame(
    data.genres.str.split('|').tolist()).stack().reset_index()
df_genre.columns = ['row_index', 'row_subindex', 'genre']
df_genre['profit_genre'] = df_genre.row_index.apply(
    lambda x: data.iloc[x]['profit'])
display(
    df_genre.pivot_table(values='profit_genre',
                         index='genre',
                         aggfunc='count',
                         margins=True).sort_values(by='profit_genre',
                                                   ascending=False).head(10))

answer_ls.append(3)
# Out:
#                  profit_genre
# genre
# All                      5112
# Drama                     782
# Comedy                    683
# Thriller                  597
# Action                    583
# Adventure                 416
# Crime                     315
# Romance                   308
# Family                    260
# Science Fiction           248

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
df_genre = pd.DataFrame(
    data.genres.str.split('|').tolist()).stack().reset_index()
df_genre.columns = ['row_index', 'row_subindex', 'genre']
df_genre['profit_genre'] = df_genre.row_index.apply(
    lambda x: data.iloc[x]['profit'])
display(df_genre[df_genre.profit_genre > 0].pivot_table(
    values='profit_genre', index='genre', aggfunc='count',
    margins=True).sort_values(by='profit_genre', ascending=False).head(10))

answer_ls.append(1)
# Out:
#                  profit_genre
# genre
# All                      3962
# Drama                     560
# Comedy                    551
# Thriller                  446
# Action                    444
# Adventure                 337
# Romance                   242
# Crime                     231
# Family                    226
# Science Fiction           195

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
df_director = pd.DataFrame(
    data.director.str.split('|').tolist()).stack().reset_index()
df_director.columns = ['row_index', 'row_subindex', 'director']
df_director['profit_director'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['profit'])
df_director['year'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
display(
    df_director.pivot_table(
        values='profit_director',
        index='director',
        aggfunc='count',
        margins=True).sort_values(by='profit_director',
                                  ascending=False).head(10))

answer_ls.append(3)
# Out:
#                    profit_director
# director
# All                           2054
# Steven Soderbergh               13
# Clint Eastwood                  12
# Ridley Scott                    12
# Robert Rodriguez                11
# Shawn Levy                      10
# Peter Farrelly                  10
# Steven Spielberg                10
# Tim Burton                       9
# Bobby Farrelly                   9

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
df_director = pd.DataFrame(
    data.director.str.split('|').tolist()).stack().reset_index()
df_director.columns = ['row_index', 'row_subindex', 'director']
df_director['profit_director'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['profit'])
df_director['year'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
display(df_director[df_director.profit_director > 0].pivot_table(
    values='profit_director', index='director', aggfunc='count',
    margins=True).sort_values(by='profit_director', ascending=False).head(10))
answer_ls.append(4)
# Out:
#                    profit_director
# director
# All                           1613
# Ridley Scott                    12
# Clint Eastwood                  10
# Steven Spielberg                10
# Steven Soderbergh               10
# Shawn Levy                       9
# Tim Burton                       9
# Christopher Nolan                8
# Peter Jackson                    8
# Peter Farrelly                   8

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
df_director = pd.DataFrame(
    data.director.str.split('|').tolist()).stack().reset_index()
df_director.columns = ['row_index', 'row_subindex', 'director']
df_director['profit_director'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['profit'])
df_director['year'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
display(
    df_director.pivot_table(
        values='profit_director',
        index='director',
        aggfunc=np.sum,
        margins=True).sort_values(by='profit_director',
                                  ascending=False).head(10))

answer_ls.append(5)
# Out:
#                    profit_director
# director
# All                   215885306303
# Peter Jackson           5202593685
# David Yates             3379295625
# Christopher Nolan       3162548502
# J.J. Abrams             2839169916
# Michael Bay             2760938960
# James Cameron           2548546718
# Francis Lawrence        2476979588
# Pierre Coffin           2452006832
# Steven Spielberg        2449700791

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
df_cast = pd.DataFrame(data.cast.str.split('|').tolist()).stack().reset_index()
df_cast.columns = ['row_index', 'row_subindex', 'cast']
df_cast['profit_cast'] = df_cast.row_index.apply(
    lambda x: data.iloc[x]['profit'])
df_cast['year'] = df_cast.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
display(
    df_cast.pivot_table(values='profit_cast',
                        index='cast',
                        aggfunc=np.sum,
                        margins=True).sort_values(by='profit_cast',
                                                  ascending=False).head(10))
answer_ls.append(1)
# Out:
#                      profit_cast
# cast
# All                 952412961817
# Emma Watson           6666245597
# Daniel Radcliffe      6514990281
# Rupert Grint          6408638290
# Ian McKellen          6087375777
# Robert Downey Jr.     5316030161
# Orlando Bloom         5148578162
# Johnny Depp           4776417000
# Ralph Fiennes         4739260140
# Michelle Rodriguez    4608031235

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
df_cast = pd.DataFrame(data.cast.str.split('|').tolist()).stack().reset_index()
df_cast.columns = ['row_index', 'row_subindex', 'cast']
df_cast['profit_cast'] = df_cast.row_index.apply(
    lambda x: int(data.iloc[x]['profit']))
df_cast['year'] = df_cast.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
pivot_cast = df_cast.pivot_table(values='profit_cast',
                                 index='cast',
                                 columns='year',
                                 aggfunc=np.sum,
                                 margins=True)
cast_2012 = pivot_cast.iloc[:, 12]
display(cast_2012.sort_values(ascending=True).head(5))
answer_ls.append(3)
# Out:
# cast
# Kirsten Dunst    -68109207.0
# Heidi Hawkins    -51893525.0
# Timothy Spall    -51893525.0
# James Kidnie     -51893525.0
# Malin Ã…kerman   -43733509.0
# Name: 2012, dtype: float64

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
df_cast = pd.DataFrame(data.cast.str.split('|').tolist()).stack().reset_index()
df_cast.columns = ['row_index', 'row_subindex', 'cast']
df_cast['budget_cast'] = df_cast.row_index.apply(
    lambda x: int(data.iloc[x]['budget']))
df_cast['year'] = df_cast.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
pivot_cast = df_cast[df_cast.budget_cast > data.budget.mean()].pivot_table(
    values='budget_cast', index='cast', aggfunc='count', margins=True)
display(pivot_cast.sort_values(by='budget_cast', ascending=False))

answer_ls.append(3)
# Out:
#                       budget_cast
# cast
# All                          3360
# Matt Damon                     18
# Adam Sandler                   17
# Angelina Jolie                 16
# Samuel L. Jackson              15
# ...                           ...
# Jennifer Hudson                 1
# Jennifer Jason Leigh            1
# Jennifer Saunders               1
# Jennifer Tilly                  1
# Josh Charles                    1
#
# [1509 rows x 1 columns]

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
df_cast = pd.DataFrame(data.cast.str.split('|').tolist()).stack().reset_index()
df_cast.columns = ['row_index', 'row_subindex', 'cast']
df_genre = pd.DataFrame(
    data.genres.str.split('|').tolist()).stack().reset_index()
df_genre.columns = ['row_index', 'row_subindex', 'genre']
df_merged = df_cast.merge(right=df_genre[['row_index', 'genre']],
                          on='row_index',
                          how='left')
display(df_merged[df_merged.cast == 'Nicolas Cage'].genre.value_counts())

answer_ls.append(2)
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Family              3
# Animation           3
# History             2
# Horror              1
# Romance             1
# War                 1
# Name: genre, dtype: int64

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_production_companies[
    'budget_production_companies'] = df_production_companies.row_index.apply(
        lambda x: int(data.iloc[x]['budget']))
df_production_companies['year'] = df_production_companies.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
pivot_production_companies = df_production_companies.pivot_table(
    values='budget_production_companies',
    index='production_companies',
    aggfunc='count',
    margins=True)
display(
    pivot_production_companies.sort_values(by='budget_production_companies',
                                           ascending=False).head(6))
answer_ls.append(4)
# Out:
#                                         budget_production_companies
# production_companies
# All                                                            6079
# Warner Bros.                                                    181
# Universal Pictures                                              173
# Paramount Pictures                                              122
# Columbia Pictures                                               117
# Twentieth Century Fox Film Corporation                          109

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_production_companies[
    'budget_production_companies'] = df_production_companies.row_index.apply(
        lambda x: int(data.iloc[x]['budget']))
df_production_companies['year'] = df_production_companies.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
pivot_production_companies = df_production_companies.pivot_table(
    values='budget_production_companies',
    columns='year',
    index='production_companies',
    aggfunc='count',
    margins=True)
production_companies_2015 = pivot_production_companies.iloc[:, 15]
display(production_companies_2015.sort_values(ascending=False).head(5))

answer_ls.append(4)
# Out:
# production_companies
# All                                       384.0
# Warner Bros.                               12.0
# Universal Pictures                         10.0
# Twentieth Century Fox Film Corporation      8.0
# Paramount Pictures                          7.0
# Name: 2015, dtype: float64

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_genre = pd.DataFrame(
    data.genres.str.split('|').tolist()).stack().reset_index()
df_genre.columns = ['row_index', 'row_subindex', 'genre']
df_merged = df_production_companies.merge(
    right=df_genre[['row_index', 'genre']], on='row_index', how='left')
df_merged['profit'] = df_merged.row_index.apply(
    lambda x: data.iloc[x]['profit'])
comedy_profit = df_merged[df_merged.genre == 'Comedy'].groupby(
    by='production_companies').aggregate('sum')
display(comedy_profit[['profit']].sort_values(by='profit', ascending=False))

answer_ls.append(2)
# Out:
#                                             profit
# production_companies
# Universal Pictures                      8961545581
# Walt Disney Pictures                    7669710326
# Twentieth Century Fox Film Corporation  5686960294
# Columbia Pictures                       5646343696
# DreamWorks Animation                    4789049764
# ...                                            ...
# Bel Air Entertainment                    -51635688
# Shangri-La Entertainment                 -55170786
# Dark Horse Entertainment                 -68351500
# Road Rebel                               -71331093
# Mel's Cite du Cinema                     -92896027
#
# [701 rows x 1 columns]

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_production_companies[
    'profit_production_companies'] = df_production_companies.row_index.apply(
        lambda x: int(data.iloc[x]['profit']))
df_production_companies['year'] = df_production_companies.row_index.apply(
    lambda x: data.iloc[x]['release_year'])
pivot_production_companies = df_production_companies.pivot_table(
    values='profit_production_companies',
    columns='year',
    index='production_companies',
    aggfunc=np.sum,
    margins=True)
production_companies_2012 = pivot_production_companies.iloc[:, 12]
display(production_companies_2012.sort_values(ascending=False).head(5))

answer_ls.append(3)
# Out:
# production_companies
# All                   4.269216e+10
# Columbia Pictures     2.501407e+09
# Universal Pictures    1.981012e+09
# Marvel Studios        1.299558e+09
# Warner Bros.          1.258020e+09
# Name: 2012, dtype: float64

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
paramount_df = data[data.production_companies.str.contains(
    'Paramount Pictures')]
#display(paramount_df[paramount_df.profit == paramount_df.profit.min()])
display(paramount_df.sort_values(by='profit').head(5))
answer_ls.append(1)
# Out:
#         imdb_id  popularity     budget   revenue        original_title  \
# 926   tt0267626    0.722330  100000000  35168966  K-19: The Widowmaker
# 1124  tt0300556    1.047214   80000000  19480739              Timeline
# 1723  tt0435705    1.068126   70000000  18211013                  Next
# 1624  tt0375173    0.898601   60000000  13395939                 Alfie
# 1632  tt0315297    0.767870   50000000  25195000               Twisted
#
#                                                    cast         director  \
# 926   Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
# 1124  Paul Walker|Frances O'Connor|Gerard Butler|Bil...   Richard Donner
# 1723  Nicolas Cage|Julianne Moore|Jessica Biel|Thoma...     Lee Tamahori
# 1624  Jude Law|Marisa Tomei|Omar Epps|Jane Krakowski...    Charles Shyer
# 1632  Ashley Judd|Samuel L. Jackson|Andy GarcÃ­a|Dav...   Philip Kaufman
#
#                                                 tagline  \
# ...

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
df_profit_year = data[['release_year',
                       'profit']].groupby(by='release_year').aggregate('sum')
display(df_profit_year.sort_values(by='profit', ascending=False))

answer_ls.append(5)
# Out:
#                    profit
# release_year
# 2015          18668572378
# 2014          16397812953
# 2012          16077001687
# 2013          15243179791
# 2011          14730241341
# 2009          13423744372
# 2010          13117292530
# 2008          11663881990
# 2007          11565911801
# 2004           9634180720
# 2003           9228823312
# 2002           9002361487
# 2005           8981925558
# 2006           8691077320
# 2001           7950614865
# 2000           6101399805

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
df_profit_year = data[data.production_companies.str.contains('Warner')][[
    'release_year', 'profit'
]].groupby(by='release_year').aggregate('sum')
display(df_profit_year.sort_values(by='profit', ascending=False))

answer_ls.append(1)
# Out:
#                   profit
# release_year
# 2014          2295464519
# 2007          2208217007
# 2008          2134595031
# 2010          1974712985
# 2011          1871393682
# 2003          1855493377
# 2009          1822454136
# 2013          1636453400
# 2004          1631933725
# 2005          1595278228
# 2001          1343545668
# 2012          1258020056
# 2002          1022709901
# 2015           870368348
# 2006           617151739
# 2000           452631386

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
display(data.release_date.apply(lambda x: x.month_name()).value_counts())
answer_ls.append(4)
# Out:
# September    227
# December     191
# October      186
# August       161
# March        156
# April        149
# June         147
# November     146
# July         142
# May          140
# February     135
# January      110
# Name: release_date, dtype: int64

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
display(
    data.release_date.apply(
        lambda x: x.month_name() in ['June', 'July', 'August']).value_counts())
answer_ls.append(2)
# Out:
# False    1440
# True      450
# Name: release_date, dtype: int64

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
df_director = pd.DataFrame(
    data.director.str.split('|').tolist()).stack().reset_index()
df_director.columns = ['row_index', 'row_subindex', 'director']
df_director['month'] = df_director.row_index.apply(
    lambda x: data.iloc[x]['release_date'].month_name())
display(
    df_director.query(
        "month in ['December','February','January']").director.value_counts())

answer_ls.append(5)
# Out:
# Peter Jackson        7
# Clint Eastwood       6
# Steven Soderbergh    6
# Adam Shankman        4
# Nancy Meyers         4
#                     ..
# Michel Gondry        1
# Alan Parker          1
# Stuart Beattie       1
# D.J. Caruso          1
# Dewey Nicks          1
# Name: director, Length: 359, dtype: int64

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
df_month_profit = data[['release_year', 'profit']].copy()
df_month_profit['month'] = data.release_date.apply(
    lambda x: x.month_name()).copy()
pivot_month_profit = df_month_profit.pivot_table(values='profit',
                                                 columns='month',
                                                 aggfunc='sum',
                                                 index='release_year')

display(pivot_month_profit.iloc[:].idxmax(axis=1).value_counts())

answer_ls.append(2)
# Out:
# June        7
# December    4
# May         4
# July        1
# dtype: int64

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_production_companies[
    'symbols_name_count'] = df_production_companies.row_index.apply(
        lambda x: len(data.iloc[x]['original_title']))
mean_len = df_production_companies[[
    'row_index', 'symbols_name_count'
]].groupby(by='row_index').aggregate('mean').mean()
display(mean_len)
df_production_companies = df_production_companies[[
    'production_companies', 'symbols_name_count'
]].groupby(by='production_companies').aggregate('mean')
display(df_production_companies[
    df_production_companies.symbols_name_count > float(mean_len)].sort_values(
        by='symbols_name_count', ascending=False))

answer_ls.append(5)
# Out:
# symbols_name_count    15.038095
# dtype: float64
#                            symbols_name_count
# production_companies
# Four By Two Productions             83.000000
# Jim Henson Company, The             59.000000
# Dos Corazones                       47.000000
# Museum Canada Productions           46.000000
# Polsky Films                        46.000000
# ...                                       ...
# Millennium Films                    15.117647
# Miramax Films                       15.102564
# Village Roadshow Pictures           15.063492
# Metro-Goldwyn-Mayer (MGM)           15.062500
# 20th Century Fox                    15.058824
#
# [645 rows x 1 columns]

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
df_production_companies = pd.DataFrame(
    data.production_companies.str.split('|').tolist()).stack().reset_index()
df_production_companies.columns = [
    'row_index', 'row_subindex', 'production_companies'
]
df_production_companies[
    'words_name_count'] = df_production_companies.row_index.apply(
        lambda x: len(str(data.iloc[x]['original_title']).split(' ')))
mean_len = df_production_companies[[
    'row_index', 'words_name_count'
]].groupby(by='row_index').aggregate('mean').mean()
display(mean_len)
df_production_companies = df_production_companies[[
    'production_companies', 'words_name_count'
]].groupby(by='production_companies').aggregate('mean')
display(df_production_companies[
    df_production_companies.words_name_count > float(mean_len)].sort_values(
        by='words_name_count', ascending=False))

answer_ls.append(5)
# Out:
# words_name_count    2.718519
# dtype: float64
#                             words_name_count
# production_companies
# Four By Two Productions            12.000000
# Jim Henson Company, The            10.000000
# The Saul Zaentz Company             9.000000
# Polsky Films                        9.000000
# Dos Corazones                       9.000000
# ...                                      ...
# Reliance BIG Entertainment          2.750000
# Miramax Films                       2.743590
# Lionsgate                           2.742857
# Columbia Pictures                   2.735043
# Warner Bros.                        2.734807
#
# [739 rows x 1 columns]

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
df_word_count = pd.DataFrame(
    data.original_title.str.split(r'\&?\s\&?').tolist()).stack().reset_index()
df_word_count.columns = ['row_index', 'row_subindex', 'word']
display(df_word_count.word.apply(lambda x: x.lower()).nunique())

answer_ls.append(3)
# Out:
# 2461

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
df_top_persent = data.sort_values(by='vote_average', ascending=False)
#display(df_top_persent)
display(data[data['vote_average'] > data.sort_values(by='vote_average',ascending=False).quantile(0.99, numeric_only=True)['vote_average']])

answer_ls.append(1)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 9     tt2096673    6.326804  175000000   853708609
# 34    tt3170832    3.557846    6000000    35401758
# 118   tt0816692   24.949134  165000000   621752480
# 119   tt2015381   14.311205  170000000   773312399
# 125   tt2084970    8.110711   14000000   233555708
# 128   tt2267998    6.438727   61000000   369330363
# 138   tt2278388    4.930820   30000000   174600318
# 370   tt1375666    9.363643  160000000   825500000
# 600   tt0468569    8.466668  185000000  1001921825
# 873   tt0253474    2.364204   35000000   120072577
# 1082  tt0167260    7.122455   94000000  1118888979
# 1184  tt0993846    4.877927  100000000   392000694
# 1192  tt2024544    3.625529   20000000   187000000
# 1801  tt0209144    3.095625    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# ...

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
"""actors_together=pd.DataFrame(data.cast.str.split('|').tolist())
actors_list=[]
for i in range(len(actors_together.index)):  
    actors_list.append(list(combinations(list(actors_together.iloc[i]),2)))
"""
actors_list=Counter(np.sum([list(combinations(actors,2))for actors in data.cast.str.split('|')])).most_common(5)

display(actors_list)

answer_ls.append(5)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8),
#  (('Daniel Radcliffe', 'Emma Watson'), 8),
#  (('Rupert Grint', 'Emma Watson'), 7),
#  (('Ben Stiller', 'Owen Wilson'), 6),
#  (('Johnny Depp', 'Helena Bonham Carter'), 6)]

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
df_director_profit=pd.DataFrame(data.director.str.split('|').to_list()).stack().reset_index()
df_director_profit.columns=['row_index','row_subindex','director']
df_director_profit['profit']=df_director_profit.row_index.apply(lambda x: data.iloc[x]['profit'] )
profit_counts=Counter(df_director_profit[df_director_profit.profit > 0].director)
counts=Counter(df_director_profit.director)
res=dict(map(lambda x: ((x),profit_counts[x]/counts[x]),counts.keys()))

display(list((x,res[x]) for x in ['Quentin Tarantino','Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']))
answer_ls.append(4)
# Out:
# [('Quentin Tarantino', 0.8571428571428571),
#  ('Steven Soderbergh', 0.7692307692307693),
#  ('Robert Rodriguez', 0.7272727272727273),
#  ('Christopher Nolan', 1.0),
#  ('Clint Eastwood', 0.8333333333333334)]

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({
    'Id': range(1,
                len(answer_ls) + 1),
    'Answer': answer_ls
},
             columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       4
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
